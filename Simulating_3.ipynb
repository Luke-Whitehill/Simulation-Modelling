# %%
#13215948 Luke Whitehill

import random
import pandas as pd
import numpy as np

# %%
cash = 15
finalamounts = []
betcount = []
winprobability = (18/37)
loseprobability = (19/37)
simulations = 100
cashlist = []
for i in range(0,simulations):
    cash = 15
    cashbalance = []
    while cash > 0 and cash < 20:
        u1 = random.uniform(0,1)
        if u1 < winprobability:
            cash += 1
        if u1 >= winprobability:
            cash -= 1
        cashbalance.append(cash)

        # print(cashbalance)
        # print(cash)
    # print(len(cashbalance))
    cashlist.append(len(cashbalance))
    finalamounts.append(cash)
# print
# (finalamounts)
win = 0
lose = 0
trapped = 0
for i in finalamounts:
    if i == 20:
        win += 1
    if i == 0:
        lose += 1
for j in cashlist:
    if j > 50:
        trapped += 1
        seventeencount = 0
        for k in cashbalance:
            if k == 17:
            seventeencount += 1
print("Seventeens",seventeencount)
# print(cashlist)
print(cashlist)
print("Probability the gambler wins: ", (win/simulations), "or ", ((win/simulations)*100), "percent of the time." )
print("The probability that the gambler is trapped for more than 50 games is: ", (trapped/simulations))
print("70%")
# Out:
#   File "<ipython-input-175-9cb5777109c5>", line 21
#     seventeencount += 1
#     ^
# IndentationError: expected an indented block

# %%
#Question 2
score = []
simulations = 1000
for i in range(0,simulations):
    u1 = random.uniform(0,1)
    if u1 < (3/6):
        result = 0
        score.append(result)
    elif u1 >= (3/6) and u1 < (4/6):
        result = 1
        score.append(result)
    elif u1 >= (4/6) and u1 < (5/6):
        result = 3
        score.append(result)
    elif u1 >= (5/6) and (u1 < 1):
        result = 5
        score.append(result)
# print(score)
print("The expect score is:",(sum(score)/simulations))
worthlessoptions = 0
onedollaroptions = 0
twodollaroptions = 0
for j in score:
    if j >= 2:
        worthlessoptions += 1
    elif j == 1:
        onedollaroptions += 1
    elif j == 0:
        twodollaroptions += 1
poptionszero = (worthlessoptions/len(score))
poptionsone = (onedollaroptions/len(score))
poptionstwo = (twodollaroptions/len(score))
probabilitycheck = poptionszero + poptionsone +poptionstwo
if probabilitycheck == 1:
    print(poptionszero, poptionsone, poptionstwo)
expectedoptionvalue = poptionszero*0+poptionsone*1+poptionstwo*2
print("Expected fair price:",expectedoptionvalue)
# Out:
# The expect score is: 1.479
# 0.339 0.162 0.499
# Expected fair price: 1.16

# %%
#Question 3
for i in range(0,1000):
    u1 = random.uniform(0,1)
    elif u1 <= 0.3:
        edges = 6
    if u1 > 0.3 and u1 < (0.3+(7/60)):
        edges = 5
    if u1 > (0.3+(7/60)) and u1 < (0.3+(7/60)+(7/60)):
        edges = 4
    if u1 > (0.3+(7/60)+(7/60)) and u1 < (0.3+(7/60)+(7/60)+(7/60))

# %%
#Question 3
edgecount = []
ablist = []
aclist = []
adlist = []
bclist = []
bdlist = []
cdlist = [] 
for i in range(0,1000):
    ab = 0
    ac = 0
    ad = 0
    bc = 0
    bd = 0
    cd = 0 
    u1 = random.uniform(0,1)
    u2 = random.uniform(0,1)
    u3 = random.uniform(0,1)
    u4 = random.uniform(0,1)
    u5 = random.uniform(0,1)
    u6 = random.uniform(0,1)
    if u1 <= 0.3:
        ab = 1
        ablist.append(ab)
    else:
        ab = 0
        ablist.append(ab)
    if u2 <= 0.3:
        ac = 1
        aclist.append(ac)
    else:
        ac = 0
        aclist.append(ac)
    if u3 <= 0.3:
        ad = 1
        adlist.append(ad)
    else:
        ad = 0
        adlist.append(ad)
    if u4 <= 0.3:
        bc = 1
        bclist.append(ac)
    else:
        bc = 0
        bclist.append(bc)
    if u5 <= 0.3:
        bd = 1
        bdlist.append(bd)
    else:
        bd = 0 
        bdlist.append(bd)
    if u6 <= 0.3:
        cd = 1
        cdlist.append(cd)
    else:
        cd = 0
        cdlist.append(cd)
    edgesum = ab+ac+ad+bc+bd+cd
    edgecount.append(edgesum)
connectedcount = 0
threeedges = 0
for j in edgecount:
    if j >= 4:
        connectedcount += 1
    if j == 3:
        threeedges += 1
print(connectedcount)
print(threeedges)

print()
# Out:
# 63
# 194

# %%
#Question 3
edgecount = []
ablist = []
aclist = []
adlist = []
bclist = []
bdlist = []
cdlist = [] 
for i in range(0,1000):
    ab = 0
    ac = 0
    ad = 0
    bc = 0
    bd = 0
    cd = 0 
    u1 = random.uniform(0,1)
    u2 = random.uniform(0,1)
    u3 = random.uniform(0,1)
    u4 = random.uniform(0,1)
    u5 = random.uniform(0,1)
    u6 = random.uniform(0,1)
    if u1 <= 0.3:
        ab = 4
        ablist.append(ab)
    else:
        ab = 0
        ablist.append(ab)
    if u2 <= 0.3:
        ac = 1
        aclist.append(ac)
    else:
        ac = 6
        aclist.append(ac)
    if u3 <= 0.3:
        ad = 1
        adlist.append(ad)
    else:
        ad = 10
        adlist.append(ad)
    if u4 <= 0.3:
        bc = 8
        bclist.append(ac)
    else:
        bc = 0
        bclist.append(bc)
    if u5 <= 0.3:
        bd = 12
        bdlist.append(bd)
    else:
        bd = 0 
        bdlist.append(bd)
    if u6 <= 0.3:
        cd = 14
        cdlist.append(cd)
    else:
        cd = 0
        cdlist.append(cd)
    edgesum = ab+ac+ad+bc+bd+cd
    edgecount.append(edgesum)
connectedcount = 0
trianglecount = 0
for j in edgecount:
    if j == 15 or j ==26 or j == 30 or j == 34:
        trianglecount += 1
print(trianglecount)


print((194-106+63)/1000)
# Out:
# 129
# 0.151
