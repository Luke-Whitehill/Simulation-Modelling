# %%
#13215948 Luke Whitehill
import random
import matplotlib.pyplot as pyplot

# %%
h = 0.002
initial_population = 1
rate = 2
population = 1
population_history = [initial_population]
#2500 steps --> 5/0.002
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population
    if u <= rate*h:
        population += 1
        population_history.append(population)
    else:
        population = population
        population_history.append(population)
    # print(population)
# print(population_history)

print(population_history[49:50],population_history[99:100],
    population_history[99:100],
    population_history[149:150],
    population_history[199:200],
    population_history[249:250],
    population_history[299:300],
    population_history[349:350],
    population_history[399:400],
    population_history[449:450],
    population_history[499:500],
    population_history[549:550],
    population_history[599:600],
    population_history[649:650],
    population_history[699:700],
    population_history[749:750],
    population_history[799:800],
    population_history[849:850],
    population_history[899:900],
    population_history[949:950],
    population_history[999:1000],
    population_history[1049:1050],
    population_history[1099:1100],
    population_history[1149:1150],
    population_history[1199:1200],
    population_history[1249:1250],
    population_history[1299:1300],
    population_history[1349:1350],
    population_history[1399:1400],
    population_history[1449:1450]
)
# Out:
# [1] [1] [1] [1] [4] [5] [6] [8] [11] [12] [14] [16] [19] [24] [28] [34] [37] [46] [52] [63] [75] [88] [108] [133] [159] [194] [234] [284] [334] [384]

# %%
pyplot.plot(population_history)
pyplot.title('Bacteria')
pyplot.xlabel('Time (seconds)')
pyplot.ylabel('Bateria Count')
pyplot.show()

# %%
h = 0.002
initial_population = 1
rate = 2
population = 1
population_history = [initial_population]
#2500 steps --> 5/0.002
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*(1-(population/200))*population
    # print(rate)
    if u <= rate*h:
        population += 1
        population_history.append(population)
    else:
        population = population
        population_history.append(population)
    # print(population)
# print(population_history)


population_total= [population_history[49:50],population_history[99:100],
    population_history[99:100],
    population_history[149:150],
    population_history[199:200],
    population_history[249:250],
    population_history[299:300],
    population_history[349:350],
    population_history[399:400],
    population_history[449:450],
    population_history[499:500],
    population_history[549:550],
    population_history[599:600],
    population_history[649:650],
    population_history[699:700],
    population_history[749:750],
    population_history[799:800],
    population_history[849:850],
    population_history[899:900],
    population_history[949:950],
    population_history[999:1000],
    population_history[1049:1050],
    population_history[1099:1100],
    population_history[1149:1150],
    population_history[1199:1200],
    population_history[1249:1250],
    population_history[1299:1300],
    population_history[1349:1350],
    population_history[1399:1400],
    population_history[1449:1450]]
print(population_history[49:50],population_history[99:100],
    population_history[99:100],
    population_history[149:150],
    population_history[199:200],
    population_history[249:250],
    population_history[299:300],
    population_history[349:350],
    population_history[399:400],
    population_history[449:450],
    population_history[499:500],
    population_history[549:550],
    population_history[599:600],
    population_history[649:650],
    population_history[699:700],
    population_history[749:750],
    population_history[799:800],
    population_history[849:850],
    population_history[899:900],
    population_history[949:950],
    population_history[999:1000],
    population_history[1049:1050],
    population_history[1099:1100],
    population_history[1149:1150],
    population_history[1199:1200],
    population_history[1249:1250],
    population_history[1299:1300],
    population_history[1349:1350],
    population_history[1399:1400],
    population_history[1449:1450]
)
print(population_total)
# Out:
# [3] [3] [3] [3] [3] [3] [5] [6] [8] [8] [9] [11] [12] [13] [16] [18] [25] [30] [38] [47] [57] [65] [73] [78] [86] [97] [112] [121] [127] [134]
# [[3], [3], [3], [3], [3], [3], [5], [6], [8], [8], [9], [11], [12], [13], [16], [18], [25], [30], [38], [47], [57], [65], [73], [78], [86], [97], [112], [121], [127], [134]]

# %%
pyplot.plot(population_history)

pyplot.title('Bacteria')
pyplot.xlabel('Time (seconds)')
pyplot.ylabel('Bateria Count')
pyplot.show()

# %%
h = 0.002
initial_population = 1
rate = 2
population = 1
population_history = [initial_population]
#2500 steps --> 5/0.002
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population
    if u <= rate*h:
        population += 1
        population_history.append(population)
    else:
        population = population
        population_history.append(population)

population_history1 = [initial_population]
population1 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population1
    if u <= rate*h:
        population1 += 1
        population_history1.append(population1)
    else:
        population1 = population1
        population_history1.append(population1)

population_history2 = [initial_population]
population2 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population2
    if u <= rate*h:
        population2 += 1
        population_history2.append(population2)
    else:
        population2 = population2
        population_history2.append(population2)


population_history3 = [initial_population]
population3 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population3
    if u <= rate*h:
        population3 += 1
        population_history3.append(population3)
    else:
        population3 = population3
        population_history3.append(population3)

population_history4 = [initial_population]
population4 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population4
    if u <= rate*h:
        population4 += 1
        population_history4.append(population4)
    else:
        population4 = population4
        population_history4.append(population4)

population_history5 = [initial_population]
population5 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population5
    if u <= rate*h:
        population5 += 1
        population_history5.append(population5)
    else:
        population5 = population5
        population_history5.append(population5)

population_history6 = [initial_population]
population6 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population6
    if u <= rate*h:
        population6 += 1
        population_history6.append(population6)
    else:
        population6 = population6
        population_history6.append(population6)

population_history7 = [initial_population]
population7 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population7
    if u <= rate*h:
        population7 += 1
        population_history7.append(population7)
    else:
        population7 = population7
        population_history7.append(population7)

population_history8 = [initial_population]
population8 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population8
    if u <= rate*h:
        population8 += 1
        population_history8.append(population8)
    else:
        population8 = population8
        population_history8.append(population8)

population_history9 = [initial_population]
population9 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population9
    if u <= rate*h:
        population9 += 1
        population_history9.append(population9)
    else:
        population9 = population9
        population_history9.append(population9)

population_history10 = [initial_population]
population10 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population10
    if u <= rate*h:
        population10 += 1
        population_history10.append(population10)
    else:
        population10 = population10
        population_history10.append(population10)

population_history11 = [initial_population]
population11 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population11
    if u <= rate*h:
        population11 += 1
        population_history11.append(population11)
    else:
        population11 = population11
        population_history11.append(population11)

population_history12 = [initial_population]
population12 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population12
    if u <= rate*h:
        population12 += 1
        population_history12.append(population12)
    else:
        population12 = population12
        population_history12.append(population12)

population_history13 = [initial_population]
population13 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population13
    if u <= rate*h:
        population13 += 1
        population_history13.append(population13)
    else:
        population13 = population13
        population_history13.append(population13)

population_history14 = [initial_population]
population14 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population14
    if u <= rate*h:
        population14 += 1
        population_history14.append(population14)
    else:
        population14 = population14
        population_history14.append(population14)


population_history15 = [initial_population]
population15 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population15
    if u <= rate*h:
        population15 += 1
        population_history15.append(population15)
    else:
        population15 = population15
        population_history15.append(population15)

population_history16 = [initial_population]
population16 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population16
    if u <= rate*h:
        population16 += 1
        population_history16.append(population16)
    else:
        population16 = population16
        population_history16.append(population16)

population_history17 = [initial_population]
population17 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population17
    if u <= rate*h:
        population17 += 1
        population_history17.append(population17)
    else:
        population17 = population17
        population_history17.append(population17)

population_history18 = [initial_population]
population18 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population18
    if u <= rate*h:
        population18 += 1
        population_history18.append(population18)
    else:
        population18 = population18
        population_history18.append(population18)


population_history19 = [initial_population]
population19 = 1
for i in range(0,2500):
    u = random.uniform(0,1)
    rate = 2*population19
    if u <= rate*h:
        population19 += 1
        population_history19.append(population19)
    else:
        population19 = population19
        population_history19.append(population19)

pyplot.plot(population_history)
pyplot.plot(population_history1)
pyplot.plot(population_history2)
pyplot.plot(population_history3)
pyplot.plot(population_history4)
pyplot.plot(population_history5)
pyplot.plot(population_history6)
pyplot.plot(population_history7)
pyplot.plot(population_history8)
pyplot.plot(population_history9)
pyplot.plot(population_history10)
pyplot.plot(population_history11)
pyplot.plot(population_history12)
pyplot.plot(population_history13)
pyplot.plot(population_history14)
pyplot.plot(population_history15)
pyplot.plot(population_history16)
pyplot.plot(population_history17)
pyplot.plot(population_history18)
pyplot.plot(population_history19)

pyplot.title('Bacteria')
pyplot.xlabel('Time (seconds)')
pyplot.ylabel('Bateria Count')
pyplot.show()
